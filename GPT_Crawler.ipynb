# %% [markdown]
# <a href="https://colab.research.google.com/github/ccwu0918/gpt-crawler/blob/main/GPT_Crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT Crawler
#
# > Crawl a site to generate knowledge files to create your own custom GPT from one or multiple URLs
#
# [https://github.com/BuilderIO/gpt-crawler](https://github.com/BuilderIO/gpt-crawler)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Configure the crawler
# Open config.ts and edit the url and selector properties to match your needs.
#
# E.g. to crawl the Builder.io docs to make our custom GPT you can use:

# %% [markdown]
# ```
# export const defaultConfig: Config = {
#   url: "https://www.builder.io/c/docs/developers",
#   match: "https://www.builder.io/c/docs/**",
#   selector: `.docs-builder-container`,
#   maxPagesToCrawl: 50,
#   outputFileName: "output.json",
# };
# ```

# %% [markdown]
# See config.ts for all available options. Here is a sample of the common configuration options:

# %% [markdown]
# ```
# type Config = {
#   /** URL to start the crawl, if sitemap is provided then it will be used instead and download all pages in the sitemap */
#   url: string;
#   /** Pattern to match against for links on a page to subsequently crawl */
#   match: string;
#   /** Selector to grab the inner text from */
#   selector: string;
#   /** Don't crawl more than this many pages */
#   maxPagesToCrawl: number;
#   /** File name for the finished data */
#   outputFileName: string;
#   /** Optional resources to exclude
#    *
#    * @example
#    * ['png','jpg','jpeg','gif','svg','css','js','ico','woff','woff2','ttf','eot','otf','mp4','mp3','webm','ogg','wav','flac','aac','zip','tar','gz','rar','7z','exe','dmg','apk','csv','xls','xlsx','doc','docx','pdf','epub','iso','dmg','bin','ppt','pptx','odt','avi','mkv','xml','json','yml','yaml','rss','atom','swf','txt','dart','webp','bmp','tif','psd','ai','indd','eps','ps','zipx','srt','wasm','m4v','m4a','webp','weba','m4b','opus','ogv','ogm','oga','spx','ogx','flv','3gp','3g2','jxr','wdp','jng','hief','avif','apng','avifs','heif','heic','cur','ico','ani','jp2','jpm','jpx','mj2','wmv','wma','aac','tif','tiff','mpg','mpeg','mov','avi','wmv','flv','swf','mkv','m4v','m4p','m4b','m4r','m4a','mp3','wav','wma','ogg','oga','webm','3gp','3g2','flac','spx','amr','mid','midi','mka','dts','ac3','eac3','weba','m3u','m3u8','ts','wpl','pls','vob','ifo','bup','svcd','drc','dsm','dsv','dsa','dss','vivo','ivf','dvd','fli','flc','flic','flic','mng','asf','m2v','asx','ram','ra','rm','rpm','roq','smi','smil','wmf','wmz','wmd','wvx','wmx','movie','wri','ins','isp','acsm','djvu','fb2','xps','oxps','ps','eps','ai','prn','svg','dwg','dxf','ttf','fnt','fon','otf','cab']
#    */
#   resourceExclusions?: string[];
#   /** Optional maximum file size in megabytes to include in the output file */
#   maxFileSize?: number;
#   /** Optional maximum number tokens to include in the output file */
#   maxTokens?: number;
# };
# ```

# %%
# !dpkg --configure -a
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg
# !NODE_MAJOR=18 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list
# !sudo apt-get update
# RUN the following commented lines to remove the previous installed nodejs (avoid conflict error)
#!sudo dpkg --remove --force-remove-reinstreq nodejs
#!sudo dpkg --remove --force-remove-reinstreq libnode-dev
#!sudo dpkg --remove --force-remove-reinstreq libnode72:amd64
# !sudo apt-get install nodejs -y
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [713 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [1,864 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# !npm -v
# Out:
# 10.4.0

# %%
# !node -v
# Out:
# v18.19.1

# %%
# !npm install -g npm@10.4.0
# Out:
# changed 14 packages in 5s
#
# 24 packages are looking for funding
#   run `npm fund` for details

# %%
# !npm install -g nodejs@latest
# Out:
# (#########⠂⠂⠂⠂⠂⠂⠂⠂⠂) ⠦ idealTree: timing idealTree Completed in 80ms
# changed 1 package in 594ms

# %%
# !npm install -g npm@latest
# !npm install -g npm
# Out:
# /tools/node/bin/npm -> /tools/node/lib/node_modules/npm/bin/npm-cli.js
# /tools/node/bin/npx -> /tools/node/lib/node_modules/npm/bin/npx-cli.js
# npm WARN notsup Unsupported engine for npm@10.4.0: wanted: {"node":"^18.17.0 || >=20.5.0"} (current: {"node":"14.16.0","npm":"6.14.8"})
# npm WARN notsup Not compatible with your version of node/npm: npm@10.4.0
#
# + npm@10.4.0
# added 91 packages from 21 contributors, removed 307 packages and updated 127 packages in 8.052s

# %%
# !git clone https://github.com/BuilderIO/gpt-crawler
# Out:
# Cloning into 'gpt-crawler'...
# remote: Enumerating objects: 660, done.
# remote: Counting objects: 100% (345/345), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 660 (delta 261), reused 218 (delta 215), pack-reused 315
# Receiving objects: 100% (660/660), 759.79 KiB | 11.51 MiB/s, done.
# Resolving deltas: 100% (379/379), done.

# %%
# %cd gpt-crawler
# Out:
# /content/gpt-crawler

# %%
# !npm i
# Out:
# > @builder.io/gpt-crawler@1.4.0 preinstall
# > npx playwright install
#
# ...

# %%
# !cat /content/gpt-crawler/config.ts
# Out:
# import { Config } from "./src/config";
#
# export const defaultConfig: Config = {
#   url: "https://www.builder.io/c/docs/developers",
#   match: "https://www.builder.io/c/docs/**",
#   maxPagesToCrawl: 50,
#   outputFileName: "output.json",
#   maxTokens: 2000000,
# };

# %%
# %%writefile /content/gpt-crawler/config.ts
# // Natural Language Processing with Python
# // – Analyzing Text with the Natural Language Toolkit
# import { Config } from "./src/config";
#
# export const defaultConfig: Config = {
#   // 爬蟲主網址
#   url: "https://www.nltk.org/book/",
#   // 網址匹配
#   match: "https://www.nltk.org/book/**",
#   // 網頁元素選擇器
#   // selector: `.docs-builder-container`,
#   // 最多爬取頁數
#   maxPagesToCrawl: 1000,
#   // 結果輸出檔案名稱：output.json
#   outputFileName: "NLP_with_Python.json",
#   maxTokens: 2000000,
# };
# Out:
# Overwriting /content/gpt-crawler/config.ts

# %%
# %%writefile /content/gpt-crawler/config.ts
#
# import { Config } from "./src/config";
#
# export const defaultConfig: Config = {
#   // 爬蟲主網址
#   url: "https://www.builder.io/c/docs/developers",
#   // 網址匹配
#   match: "https://www.builder.io/c/docs/**",
#   // 網頁元素選擇器
#   selector: `.docs-builder-container`,
#   // 最多爬取頁數
#   maxPagesToCrawl: 1000,
#   // 結果輸出檔案名稱：output.json
#   outputFileName: "builder-io.json",
#   maxTokens: 2000000,
# };
# Out:
# Overwriting /content/gpt-crawler/config.ts

# %%
# !npm start
# Out:
# > @builder.io/gpt-crawler@1.4.0 start
# > npm run start:dev
#
#
# > @builder.io/gpt-crawler@1.4.0 start:dev
# > cross-env NODE_ENV=development npm run build && node dist/src/main.js
#
#
# > @builder.io/gpt-crawler@1.4.0 build
# > tsc
#
# INFO  PlaywrightCrawler: Starting the crawler.
# INFO  PlaywrightCrawler: Crawling: Page 1 / 1000 - URL: https://www.nltk.org/book/...
# INFO  PlaywrightCrawler: Crawling: Page 2 / 1000 - URL: https://www.nltk.org/book/ch00.html...
# INFO  PlaywrightCrawler: Crawling: Page 3 / 1000 - URL: https://www.nltk.org/book/ch01.html...
# INFO  PlaywrightCrawler: Crawling: Page 4 / 1000 - URL: https://www.nltk.org/book/ch02.html...
# INFO  PlaywrightCrawler: Crawling: Page 5 / 1000 - URL: https://www.nltk.org/book/ch03.html...
# INFO  PlaywrightCrawler: Crawling: Page 6 / 1000 - URL: https://www.nltk.org/book/ch04.html...
# INFO  PlaywrightCrawler: Crawling: Page 7 / 1000 - URL: https://www.nltk.org/book/ch05.html...
# ...
